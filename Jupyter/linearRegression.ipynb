# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
import os
os.listdir()
df = pd.read_excel('syntheticData.xlsx')
df.head()
# Out:
#   Section Code  Homework Assignment 1 Submission   \
# 0         s021                                0.0
# 1         s021                                0.0
# 2         s021                              100.0
# 3         s021                               96.0
# 4         s021                              100.0
#
#    Homework Assignment 2 Submission   Homework Assignment 3 Submission   \
# 0                                0.0                                0.0
# 1                               80.0                               74.0
# 2                               78.0                               83.0
# 3                               87.0                               69.0
# 4                               88.0                               62.0
#
#    Homework Assignment 4 Submission   Homework Assignment 5 Submission   \
# 0                               54.0                               77.0
# 1                               92.0                               77.0
# ...

# %%
df[['Term']] = df['Term'].str.split("T").str[1]
df[['Season']] = df['Season'].str.split("S").str[1]
df[['Year']] = df['Year'].str.split("Y").str[1]
df[['Type']] = df['Type'].str.split("T").str[1]
df[['Instructor']] = df['Instructor'].str.split("Prof").str[1]
df[['GTA']] = df['GTA'].str.split("GTA").str[1]
df[['Section Code']] = df['Section Code'].str.split("s").str[1]

# %%
df.head()
# Out:
#   Section Code  Homework Assignment 1 Submission   \
# 0          021                                0.0
# 1          021                                0.0
# 2          021                              100.0
# 3          021                               96.0
# 4          021                              100.0
#
#    Homework Assignment 2 Submission   Homework Assignment 3 Submission   \
# 0                                0.0                                0.0
# 1                               80.0                               74.0
# 2                               78.0                               83.0
# 3                               87.0                               69.0
# 4                               88.0                               62.0
#
#    Homework Assignment 4 Submission   Homework Assignment 5 Submission   \
# 0                               54.0                               77.0
# 1                               92.0                               77.0
# ...

# %%
X = df.drop('Total ', axis=1)
y = df['Total ']

# %%
labelEncoder = LabelEncoder()

cat_columns = X.dtypes.pipe(lambda x: x[x == 'object']).index

for col in cat_columns:
    X[col] = labelEncoder.fit_transform(X[col])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
np.any(np.isnan(X_train))
X_train = np.nan_to_num(X_train)

# %%
mod = LinearRegression()
fi = mod.fit(X_train, y_train)
pred = fi.predict(X_test)

# %%
print('Coefficients: \n', mod.coef_)
print("Mean squared error: %.2f" %mean_squared_error(y_test, pred))
print('Variance score: %.2f' %r2_score(y_test, pred))
# Out:
# Coefficients:
#  [-2.80453303e-14 -9.43689571e-16  4.94913214e-16 -1.89127043e-16
#  -1.79256513e-15 -2.73949220e-15  7.30544804e-16  6.66011886e-16
#   1.33713465e-15  3.37619647e-16 -6.56084073e-16  1.93269361e-15
#  -4.28571429e-01 -4.28571429e-01 -1.42857143e-01  5.71428571e-01
#  -6.90475062e-14  1.12872222e-14 -2.89499327e-14  5.48779094e-14
#  -3.23558454e-15  5.72252749e-15]
# Mean squared error: 0.00
# Variance score: 1.00
