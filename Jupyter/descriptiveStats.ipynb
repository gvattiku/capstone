# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
root = r'C:\Users\vatti\Downloads'
os.chdir(root)

# %%
realData = pd.read_excel('realData.xlsx')
syntheticData = pd.read_csv('syntheticData.csv')
syntheticData = syntheticData.drop(labels = 'Unnamed: 0', axis = 1)

# %%
plt.show(realData.boxplot(column = ['Homework Assignment 1 Submission ', 'Homework Assignment 2 Submission ', 'Homework Assignment 3 Submission ', 'Homework Assignment 4 Submission ', 'Homework Assignment 5 Submission ', 'Average Quizzes', 'Course Grade Without Extra Credit '], rot = 90, grid = False))

# %%
plt.show(syntheticData.boxplot(column = ['HW1', 'HW2', 'HW3', 'HW4', 'HW5', 'Quizzes', 'Course.Grade.with.No.extra.credit'], rot = 90, grid = False))
